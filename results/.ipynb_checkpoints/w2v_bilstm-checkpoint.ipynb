# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')


import pandas as pd
import gensim
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Embedding, Bidirectional
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import precision_score, recall_score, accuracy_score, classification_report
import keras
from gensim.models import KeyedVectors
import os
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
# directory_file_path = '/content/drive/My Drive/final_dataset/resampling'

# # Loop through the files in the directory to check file names
# for filename in os.listdir(directory_file_path):
#     if filename.endswith('.csv'):  # Check if the file ends with .csv
#         name = os.path.join(directory_file_path, filename)
#         print(name)

# %%
word2vec_path = r'/content/drive/My Drive/GoogleNews-vectors-negative300.bin'
w2v_model = KeyedVectors.load_word2vec_format(word2vec_path, binary=True)


def w2v_bilstm(df):
    df = df.dropna(subset=['processed'])

    df = df[['processed', 'label']]
    df['label'] = df['label'].map({'neu':0, 'pos':1, 'neg':2})

    df['processed'] =  [x.split() for x in df['processed']]
    X_train, X_test, y_train, y_test = train_test_split (df['processed'], df['label'] , test_size=0.2)

    words = set(w2v_model.index_to_key)
    word_to_idx = {word: i+1 for i, word in enumerate(words)}  # 0 is reserved for padding

    # Convert text to sequences of indices
    def text_to_sequence(text):
        return [word_to_idx.get(word, 0) for word in text if word in words]

    X_train_seq = [text_to_sequence(text) for text in X_train]
    X_test_seq = [text_to_sequence(text) for text in X_test]

    max_length = max(len(seq) for seq in X_train_seq)

    # Pad sequences
    X_train_padded = pad_sequences(X_train_seq, maxlen=max_length, padding='post')
    X_test_padded = pad_sequences(X_test_seq, maxlen=max_length, padding='post')

    # Create embedding matrix
    vocab_size = len(word_to_idx) + 1  # +1 for padding token
    print(f'vocab size: {vocab_size}')
    embedding_matrix = np.zeros((vocab_size, 300))
    for word, i in word_to_idx.items():
        embedding_matrix[i] = w2v_model[word]
    # print(embedding_matrix)

    # To stop the training of the model earlier if 3 consecutive loss stays the same (does not decrease)
    callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3, mode='min')

    # Build the model
    model = Sequential()
    model.add(Embedding(input_dim=vocab_size, output_dim=300, weights=[embedding_matrix], input_length=max_length, trainable=False))
    model.add(Bidirectional(LSTM(128, return_sequences=True)))
    model.add(Dropout(0.2))
    model.add(Bidirectional(LSTM(64)))
    model.add(Dropout(0.2))
    model.add(Dense(3, activation='softmax'))

    # Step 4: Compile the model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train_padded, y_train, epochs=50, batch_size=32, validation_split=0.2, callbacks=[callback])

    # Step 6: Predict on test data
    y_pred = model.predict(X_test_padded)
    y_pred

    # Convert probabilities to class labels
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_pred_labels

    # Convert y_pred_labels to a pandas Series
    y_pred_series = pd.Series(y_pred_labels, index=y_test.index)
    y_pred_series

    # step 8: results (word2vec (pretrained-googlenews) + bidirectional LSTM)
    # Tesing on original_df dataset

    # {'neu':0, 'pos':1, 'neg':2}
    target_names = ["neu", "pos", "neg"]

    report_dict = classification_report(y_test, y_pred_series, target_names=target_names, output_dict=True)

    # Convert the report dictionary into a DataFrame for better readability
    report_df = pd.DataFrame(report_dict).transpose()

    # Create an empty row with NaN values
    empty_row = pd.DataFrame([[" "] * len(report_df.columns)], columns=report_df.columns)

    # Insert the empty row after 'neg' to separate the row for readability
    report_df = pd.concat([report_df.loc[:'neg'], empty_row, report_df.loc['accuracy':]], ignore_index=False)

    report_df.index.values[3] = ' '

    # Display the summary
    print("")
    print(report_df)

# %%
# path_1 = os.path.join('Data/final_dataset/', 'COVIDSenti-A_cleanest.csv')
# path_under = '/content/drive/My Drive/final_dataset/resampling/COVIDSenti_cleanest_over.csv'
# df = pd.read_csv(path_under, encoding='utf-8')

# w2v_bilstm(df)


# directory_file_path = '/content/drive/My Drive/final_dataset/'
# file_l = []
# # Loop through the files in the directory to check file names
# for filename in os.listdir(directory_file_path):
#   if filename.endswith('.csv'):
#     file_l.append(filename)  # Check if the file ends with .csv
#     print(filename)

file_l = ['/content/drive/My Drive/final_dataset/COVIDSenti-C_mostfeature.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-B_origin_over.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-B_origin_under.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_mostfeature_over.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_mostfeature_under.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_cleanest_over.csv',
          '/content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_cleanest_under.csv']

for i in file_l:
  path = i
  print('#'*30, '\n', i,'\n start')
  df = pd.read_csv(path, encoding='utf-8')
  w2v_bilstm(df)
# Out:
# ##############################
#  /content/drive/My Drive/final_dataset/COVIDSenti-C_mostfeature.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 600/600 [==============================] - 25s 32ms/step - loss: 0.6076 - accuracy: 0.7720 - val_loss: 0.5336 - val_accuracy: 0.8037
# Epoch 2/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.4890 - accuracy: 0.8209 - val_loss: 0.4758 - val_accuracy: 0.8294
# Epoch 3/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.4309 - accuracy: 0.8441 - val_loss: 0.4525 - val_accuracy: 0.8408
# Epoch 4/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.3807 - accuracy: 0.8652 - val_loss: 0.4522 - val_accuracy: 0.8467
# Epoch 5/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.3312 - accuracy: 0.8834 - val_loss: 0.4305 - val_accuracy: 0.8502
# Epoch 6/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.2797 - accuracy: 0.9018 - val_loss: 0.4508 - val_accuracy: 0.8533
# Epoch 7/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.2278 - accuracy: 0.9183 - val_loss: 0.5119 - val_accuracy: 0.8483
# Epoch 8/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.1793 - accuracy: 0.9364 - val_loss: 0.5521 - val_accuracy: 0.8438
# Epoch 9/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.1375 - accuracy: 0.9510 - val_loss: 0.6142 - val_accuracy: 0.8385
# Epoch 10/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.1066 - accuracy: 0.9635 - val_loss: 0.7201 - val_accuracy: 0.8423
# Epoch 11/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0840 - accuracy: 0.9719 - val_loss: 0.7310 - val_accuracy: 0.8435
# Epoch 12/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0638 - accuracy: 0.9797 - val_loss: 0.8626 - val_accuracy: 0.8281
# Epoch 13/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0618 - accuracy: 0.9792 - val_loss: 0.8113 - val_accuracy: 0.8273
# Epoch 14/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0542 - accuracy: 0.9821 - val_loss: 0.8776 - val_accuracy: 0.8396
# Epoch 15/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0395 - accuracy: 0.9868 - val_loss: 0.9730 - val_accuracy: 0.8388
# Epoch 16/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0355 - accuracy: 0.9875 - val_loss: 0.9667 - val_accuracy: 0.8356
# Epoch 17/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 1.0143 - val_accuracy: 0.8350
# Epoch 18/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 1.0293 - val_accuracy: 0.8392
# Epoch 19/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0288 - accuracy: 0.9909 - val_loss: 1.0311 - val_accuracy: 0.8431
# Epoch 20/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0260 - accuracy: 0.9905 - val_loss: 1.1047 - val_accuracy: 0.8465
# Epoch 21/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 1.0812 - val_accuracy: 0.8392
# Epoch 22/50
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0187 - accuracy: 0.9946 - val_loss: 1.2371 - val_accuracy: 0.8392
# Epoch 23/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0268 - accuracy: 0.9910 - val_loss: 1.0083 - val_accuracy: 0.8433
# Epoch 24/50
# 600/600 [==============================] - 18s 30ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 1.0253 - val_accuracy: 0.8440
# Epoch 25/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 1.1397 - val_accuracy: 0.8440
# Epoch 26/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 1.0554 - val_accuracy: 0.8452
# Epoch 27/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 1.1807 - val_accuracy: 0.8431
# Epoch 28/50
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 1.1112 - val_accuracy: 0.8175
# 188/188 [==============================] - 3s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.882554  0.885178  0.883864    4372.0
# pos           0.562201  0.525727  0.543353     447.0
# neg           0.705096  0.714649   0.70984    1181.0
#
# accuracy      0.824833  0.824833  0.824833  0.824833
# macro avg     0.716617  0.708518  0.712352    6000.0
# weighted avg  0.823758  0.824833  0.824242    6000.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-B_origin_over.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 1344/1344 [==============================] - 51s 34ms/step - loss: 0.6884 - accuracy: 0.7030 - val_loss: 0.5188 - val_accuracy: 0.7905
# Epoch 2/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.4092 - accuracy: 0.8399 - val_loss: 0.3584 - val_accuracy: 0.8654
# Epoch 3/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.2656 - accuracy: 0.9017 - val_loss: 0.2856 - val_accuracy: 0.8954
# Epoch 4/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.1812 - accuracy: 0.9373 - val_loss: 0.2231 - val_accuracy: 0.9264
# Epoch 5/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.1294 - accuracy: 0.9566 - val_loss: 0.2135 - val_accuracy: 0.9328
# Epoch 6/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0920 - accuracy: 0.9701 - val_loss: 0.1867 - val_accuracy: 0.9440
# Epoch 7/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0716 - accuracy: 0.9767 - val_loss: 0.1941 - val_accuracy: 0.9491
# Epoch 8/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0542 - accuracy: 0.9829 - val_loss: 0.2152 - val_accuracy: 0.9430
# Epoch 9/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0470 - accuracy: 0.9846 - val_loss: 0.1940 - val_accuracy: 0.9537
# Epoch 10/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0352 - accuracy: 0.9891 - val_loss: 0.1926 - val_accuracy: 0.9580
# Epoch 11/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0363 - accuracy: 0.9888 - val_loss: 0.2203 - val_accuracy: 0.9477
# Epoch 12/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0289 - accuracy: 0.9902 - val_loss: 0.2142 - val_accuracy: 0.9529
# Epoch 13/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.2118 - val_accuracy: 0.9550
# Epoch 14/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0222 - accuracy: 0.9927 - val_loss: 0.2379 - val_accuracy: 0.9573
# Epoch 15/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.3223 - val_accuracy: 0.9407
# Epoch 16/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0216 - accuracy: 0.9933 - val_loss: 0.2803 - val_accuracy: 0.9507
# Epoch 17/50
# 1344/1344 [==============================] - 45s 34ms/step - loss: 0.0196 - accuracy: 0.9938 - val_loss: 0.2227 - val_accuracy: 0.9598
# Epoch 18/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 0.2455 - val_accuracy: 0.9562
# Epoch 19/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.2331 - val_accuracy: 0.9575
# Epoch 20/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.2701 - val_accuracy: 0.9561
# Epoch 21/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0141 - accuracy: 0.9956 - val_loss: 0.2468 - val_accuracy: 0.9610
# Epoch 22/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.2584 - val_accuracy: 0.9589
# Epoch 23/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.2225 - val_accuracy: 0.9609
# Epoch 24/50
# 1344/1344 [==============================] - 45s 34ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.2366 - val_accuracy: 0.9573
# Epoch 25/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.2606 - val_accuracy: 0.9568
# Epoch 26/50
# 1344/1344 [==============================] - 45s 33ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.2698 - val_accuracy: 0.9563
# Epoch 27/50
# 1344/1344 [==============================] - 44s 33ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.2040 - val_accuracy: 0.9637
# 420/420 [==============================] - 6s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.977929   0.91263  0.944152    4418.0
# pos           0.970808  0.999781  0.985081    4557.0
# neg           0.945864  0.979592  0.962433    4459.0
#
# accuracy      0.964419  0.964419  0.964419  0.964419
# macro avg     0.964867  0.964001  0.963888   13434.0
# weighted avg   0.96487  0.964419  0.964103   13434.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-B_origin_under.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 122/122 [==============================] - 10s 43ms/step - loss: 0.9662 - accuracy: 0.5239 - val_loss: 0.8745 - val_accuracy: 0.6029
# Epoch 2/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.8293 - accuracy: 0.6250 - val_loss: 0.8496 - val_accuracy: 0.6039
# Epoch 3/50
# 122/122 [==============================] - 4s 33ms/step - loss: 0.7522 - accuracy: 0.6762 - val_loss: 0.8615 - val_accuracy: 0.6101
# Epoch 4/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.6804 - accuracy: 0.7065 - val_loss: 0.8304 - val_accuracy: 0.6368
# Epoch 5/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.6168 - accuracy: 0.7353 - val_loss: 0.8024 - val_accuracy: 0.6389
# Epoch 6/50
# 122/122 [==============================] - 4s 33ms/step - loss: 0.5500 - accuracy: 0.7773 - val_loss: 0.8090 - val_accuracy: 0.6749
# Epoch 7/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.4692 - accuracy: 0.8099 - val_loss: 0.8710 - val_accuracy: 0.6636
# Epoch 8/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.3875 - accuracy: 0.8498 - val_loss: 0.9113 - val_accuracy: 0.6574
# Epoch 9/50
# 122/122 [==============================] - 4s 33ms/step - loss: 0.3151 - accuracy: 0.8783 - val_loss: 1.0619 - val_accuracy: 0.6605
# Epoch 10/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.2565 - accuracy: 0.9015 - val_loss: 1.0642 - val_accuracy: 0.6667
# Epoch 11/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.2011 - accuracy: 0.9241 - val_loss: 1.1863 - val_accuracy: 0.6646
# Epoch 12/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.1511 - accuracy: 0.9434 - val_loss: 1.4270 - val_accuracy: 0.6759
# Epoch 13/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.1191 - accuracy: 0.9594 - val_loss: 1.4744 - val_accuracy: 0.6770
# Epoch 14/50
# 122/122 [==============================] - 4s 33ms/step - loss: 0.0992 - accuracy: 0.9650 - val_loss: 1.4257 - val_accuracy: 0.6800
# Epoch 15/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0723 - accuracy: 0.9745 - val_loss: 1.7826 - val_accuracy: 0.6708
# Epoch 16/50
# 122/122 [==============================] - 4s 33ms/step - loss: 0.0665 - accuracy: 0.9794 - val_loss: 1.7573 - val_accuracy: 0.6698
# Epoch 17/50
# 122/122 [==============================] - 4s 31ms/step - loss: 0.0657 - accuracy: 0.9774 - val_loss: 1.7308 - val_accuracy: 0.6687
# Epoch 18/50
# 122/122 [==============================] - 4s 31ms/step - loss: 0.0432 - accuracy: 0.9869 - val_loss: 1.8761 - val_accuracy: 0.6677
# Epoch 19/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0427 - accuracy: 0.9866 - val_loss: 1.8101 - val_accuracy: 0.6656
# Epoch 20/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0500 - accuracy: 0.9817 - val_loss: 1.6499 - val_accuracy: 0.6903
# Epoch 21/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 1.9172 - val_accuracy: 0.6821
# Epoch 22/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0154 - accuracy: 0.9969 - val_loss: 2.0867 - val_accuracy: 0.6749
# Epoch 23/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0291 - accuracy: 0.9918 - val_loss: 1.9883 - val_accuracy: 0.6749
# Epoch 24/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0329 - accuracy: 0.9859 - val_loss: 1.9395 - val_accuracy: 0.6626
# Epoch 25/50
# 122/122 [==============================] - 4s 32ms/step - loss: 0.0444 - accuracy: 0.9864 - val_loss: 1.9547 - val_accuracy: 0.6770
# 38/38 [==============================] - 2s 13ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.585132  0.605459  0.595122     403.0
# pos           0.698254  0.712468   0.70529     393.0
# neg           0.738035  0.699284  0.718137     419.0
#
# accuracy      0.672428  0.672428  0.672428  0.672428
# macro avg     0.673807  0.672404   0.67285    1215.0
# weighted avg  0.674452  0.672428  0.673179    1215.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_mostfeature_over.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 1317/1317 [==============================] - 49s 33ms/step - loss: 0.6874 - accuracy: 0.7051 - val_loss: 0.5216 - val_accuracy: 0.7897
# Epoch 2/50
# 1317/1317 [==============================] - 43s 32ms/step - loss: 0.4212 - accuracy: 0.8391 - val_loss: 0.3736 - val_accuracy: 0.8600
# Epoch 3/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.2809 - accuracy: 0.8998 - val_loss: 0.2902 - val_accuracy: 0.8953
# Epoch 4/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.1924 - accuracy: 0.9347 - val_loss: 0.2360 - val_accuracy: 0.9204
# Epoch 5/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.1336 - accuracy: 0.9564 - val_loss: 0.2291 - val_accuracy: 0.9264
# Epoch 6/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0995 - accuracy: 0.9677 - val_loss: 0.2208 - val_accuracy: 0.9381
# Epoch 7/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0802 - accuracy: 0.9738 - val_loss: 0.2192 - val_accuracy: 0.9418
# Epoch 8/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0585 - accuracy: 0.9812 - val_loss: 0.1949 - val_accuracy: 0.9481
# Epoch 9/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0496 - accuracy: 0.9838 - val_loss: 0.2518 - val_accuracy: 0.9370
# Epoch 10/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0413 - accuracy: 0.9873 - val_loss: 0.2832 - val_accuracy: 0.9347
# Epoch 11/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0340 - accuracy: 0.9889 - val_loss: 0.2818 - val_accuracy: 0.9398
# Epoch 12/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0323 - accuracy: 0.9895 - val_loss: 0.2639 - val_accuracy: 0.9433
# Epoch 13/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.2421 - val_accuracy: 0.9506
# Epoch 14/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0265 - accuracy: 0.9920 - val_loss: 0.3372 - val_accuracy: 0.9411
# Epoch 15/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.2586 - val_accuracy: 0.9510
# Epoch 16/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.2489 - val_accuracy: 0.9537
# Epoch 17/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.2927 - val_accuracy: 0.9509
# Epoch 18/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.2923 - val_accuracy: 0.9480
# Epoch 19/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.2529 - val_accuracy: 0.9527
# Epoch 20/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.3096 - val_accuracy: 0.9494
# Epoch 21/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.2677 - val_accuracy: 0.9539
# Epoch 22/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.2807 - val_accuracy: 0.9541
# Epoch 23/50
# 1317/1317 [==============================] - 42s 32ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.3135 - val_accuracy: 0.9549
# 412/412 [==============================] - 6s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.972215  0.897615  0.933427    4444.0
# pos            0.96544  0.996089  0.980525    4347.0
# neg           0.934003  0.977361  0.955191    4373.0
#
# accuracy      0.956624  0.956624  0.956624  0.956624
# macro avg      0.95722  0.957022  0.956381   13164.0
# weighted avg  0.957284  0.956624  0.956209   13164.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_mostfeature_under.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 137/137 [==============================] - 11s 42ms/step - loss: 0.9577 - accuracy: 0.5374 - val_loss: 0.8639 - val_accuracy: 0.6234
# Epoch 2/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.7949 - accuracy: 0.6480 - val_loss: 0.8622 - val_accuracy: 0.6179
# Epoch 3/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.7212 - accuracy: 0.6949 - val_loss: 0.8218 - val_accuracy: 0.6600
# Epoch 4/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.6543 - accuracy: 0.7255 - val_loss: 0.7815 - val_accuracy: 0.6728
# Epoch 5/50
# 137/137 [==============================] - 5s 33ms/step - loss: 0.5789 - accuracy: 0.7595 - val_loss: 0.8120 - val_accuracy: 0.6700
# Epoch 6/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.4979 - accuracy: 0.8023 - val_loss: 0.8238 - val_accuracy: 0.6682
# Epoch 7/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.4351 - accuracy: 0.8265 - val_loss: 0.8317 - val_accuracy: 0.6737
# Epoch 8/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.3676 - accuracy: 0.8587 - val_loss: 0.9615 - val_accuracy: 0.6563
# Epoch 9/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.2987 - accuracy: 0.8853 - val_loss: 1.0417 - val_accuracy: 0.6527
# Epoch 10/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.2519 - accuracy: 0.9067 - val_loss: 1.0266 - val_accuracy: 0.6654
# Epoch 11/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1925 - accuracy: 0.9289 - val_loss: 1.1919 - val_accuracy: 0.6435
# Epoch 12/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1629 - accuracy: 0.9442 - val_loss: 1.1722 - val_accuracy: 0.6654
# Epoch 13/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1170 - accuracy: 0.9623 - val_loss: 1.3749 - val_accuracy: 0.6737
# Epoch 14/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0985 - accuracy: 0.9687 - val_loss: 1.3639 - val_accuracy: 0.6664
# Epoch 15/50
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0784 - accuracy: 0.9762 - val_loss: 1.8325 - val_accuracy: 0.6554
# Epoch 16/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0601 - accuracy: 0.9797 - val_loss: 1.6518 - val_accuracy: 0.6636
# Epoch 17/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.0929 - accuracy: 0.9689 - val_loss: 1.6450 - val_accuracy: 0.6792
# Epoch 18/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0523 - accuracy: 0.9829 - val_loss: 1.7001 - val_accuracy: 0.6490
# Epoch 19/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0457 - accuracy: 0.9840 - val_loss: 1.7861 - val_accuracy: 0.6481
# Epoch 20/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.0369 - accuracy: 0.9886 - val_loss: 1.8492 - val_accuracy: 0.6536
# Epoch 21/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0443 - accuracy: 0.9874 - val_loss: 1.9734 - val_accuracy: 0.6654
# Epoch 22/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0315 - accuracy: 0.9904 - val_loss: 2.2122 - val_accuracy: 0.6527
# Epoch 23/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0371 - accuracy: 0.9883 - val_loss: 1.9768 - val_accuracy: 0.6563
# Epoch 24/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0334 - accuracy: 0.9902 - val_loss: 1.9416 - val_accuracy: 0.6636
# Epoch 25/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0416 - accuracy: 0.9863 - val_loss: 1.9890 - val_accuracy: 0.6581
# 43/43 [==============================] - 2s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.601322  0.605322  0.603315     451.0
# pos           0.751807   0.65272  0.698768     478.0
# neg           0.707415    0.8041  0.752665     439.0
#
# accuracy      0.685673  0.685673  0.685673  0.685673
# macro avg     0.686848   0.68738  0.684916    1368.0
# weighted avg   0.68795  0.685673  0.684595    1368.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_cleanest_over.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 1310/1310 [==============================] - 49s 33ms/step - loss: 0.6905 - accuracy: 0.7010 - val_loss: 0.5673 - val_accuracy: 0.7618
# Epoch 2/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.4219 - accuracy: 0.8365 - val_loss: 0.3467 - val_accuracy: 0.8726
# Epoch 3/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.2683 - accuracy: 0.9026 - val_loss: 0.2814 - val_accuracy: 0.9004
# Epoch 4/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.1805 - accuracy: 0.9378 - val_loss: 0.2212 - val_accuracy: 0.9285
# Epoch 5/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.1264 - accuracy: 0.9584 - val_loss: 0.2026 - val_accuracy: 0.9341
# Epoch 6/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0941 - accuracy: 0.9702 - val_loss: 0.1927 - val_accuracy: 0.9435
# Epoch 7/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0732 - accuracy: 0.9766 - val_loss: 0.1878 - val_accuracy: 0.9459
# Epoch 8/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0606 - accuracy: 0.9809 - val_loss: 0.1835 - val_accuracy: 0.9505
# Epoch 9/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0457 - accuracy: 0.9859 - val_loss: 0.2085 - val_accuracy: 0.9487
# Epoch 10/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 0.1940 - val_accuracy: 0.9545
# Epoch 11/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 0.1956 - val_accuracy: 0.9563
# Epoch 12/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0295 - accuracy: 0.9910 - val_loss: 0.1957 - val_accuracy: 0.9561
# Epoch 13/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 0.1999 - val_accuracy: 0.9589
# Epoch 14/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.2248 - val_accuracy: 0.9538
# Epoch 15/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.2276 - val_accuracy: 0.9575
# Epoch 16/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.2193 - val_accuracy: 0.9549
# Epoch 17/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.2460 - val_accuracy: 0.9568
# Epoch 18/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.1874 - val_accuracy: 0.9650
# Epoch 19/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0159 - accuracy: 0.9953 - val_loss: 0.2686 - val_accuracy: 0.9553
# Epoch 20/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.2207 - val_accuracy: 0.9597
# Epoch 21/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.2361 - val_accuracy: 0.9563
# Epoch 22/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.2505 - val_accuracy: 0.9577
# Epoch 23/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.2129 - val_accuracy: 0.9617
# Epoch 24/50
# 1310/1310 [==============================] - 41s 32ms/step - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.2131 - val_accuracy: 0.9630
# Epoch 25/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.2564 - val_accuracy: 0.9603
# Epoch 26/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.2611 - val_accuracy: 0.9574
# Epoch 27/50
# 1310/1310 [==============================] - 42s 32ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.2780 - val_accuracy: 0.9512
# 410/410 [==============================] - 6s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu           0.980098  0.868331  0.920835    4367.0
# pos           0.965642  0.995804  0.980491    4290.0
# neg           0.909867  0.984459  0.945695    4440.0
#
# accuracy      0.949454  0.949454  0.949454  0.949454
# macro avg     0.951869  0.949531  0.949007   13097.0
# weighted avg  0.951554  0.949454  0.948803   13097.0
# ##############################
#  /content/drive/My Drive/final_dataset/resampling/COVIDSenti-C_cleanest_under.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 137/137 [==============================] - 11s 43ms/step - loss: 0.9560 - accuracy: 0.5411 - val_loss: 0.8400 - val_accuracy: 0.6235
# Epoch 2/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.7965 - accuracy: 0.6511 - val_loss: 0.7872 - val_accuracy: 0.6612
# Epoch 3/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.7181 - accuracy: 0.6991 - val_loss: 0.7741 - val_accuracy: 0.6621
# Epoch 4/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.6463 - accuracy: 0.7244 - val_loss: 0.7559 - val_accuracy: 0.6758
# Epoch 5/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.5733 - accuracy: 0.7680 - val_loss: 0.8171 - val_accuracy: 0.6740
# Epoch 6/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.5076 - accuracy: 0.7951 - val_loss: 0.7771 - val_accuracy: 0.6887
# Epoch 7/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.4318 - accuracy: 0.8305 - val_loss: 0.8464 - val_accuracy: 0.6823
# Epoch 8/50
# 137/137 [==============================] - 4s 33ms/step - loss: 0.3868 - accuracy: 0.8461 - val_loss: 0.9529 - val_accuracy: 0.6814
# Epoch 9/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.3082 - accuracy: 0.8817 - val_loss: 0.9475 - val_accuracy: 0.6860
# Epoch 10/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.2820 - accuracy: 0.8930 - val_loss: 1.0450 - val_accuracy: 0.6933
# Epoch 11/50
# 137/137 [==============================] - 4s 31ms/step - loss: 0.2198 - accuracy: 0.9201 - val_loss: 1.1657 - val_accuracy: 0.6520
# Epoch 12/50
# 137/137 [==============================] - 4s 31ms/step - loss: 0.1731 - accuracy: 0.9382 - val_loss: 1.1937 - val_accuracy: 0.6979
# Epoch 13/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1408 - accuracy: 0.9513 - val_loss: 1.3180 - val_accuracy: 0.6749
# Epoch 14/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0917 - accuracy: 0.9713 - val_loss: 1.5333 - val_accuracy: 0.6703
# Epoch 15/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1044 - accuracy: 0.9626 - val_loss: 1.4376 - val_accuracy: 0.6942
# Epoch 16/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.1430 - accuracy: 0.9522 - val_loss: 1.4212 - val_accuracy: 0.6942
# Epoch 17/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0679 - accuracy: 0.9763 - val_loss: 1.5683 - val_accuracy: 0.6749
# Epoch 18/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0459 - accuracy: 0.9846 - val_loss: 1.8037 - val_accuracy: 0.6979
# Epoch 19/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0396 - accuracy: 0.9874 - val_loss: 1.8375 - val_accuracy: 0.6777
# Epoch 20/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0599 - accuracy: 0.9805 - val_loss: 1.6644 - val_accuracy: 0.6786
# Epoch 21/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 1.9177 - val_accuracy: 0.6915
# Epoch 22/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 1.7794 - val_accuracy: 0.7034
# Epoch 23/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 2.0479 - val_accuracy: 0.6768
# Epoch 24/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0104 - accuracy: 0.9970 - val_loss: 2.0933 - val_accuracy: 0.6924
# Epoch 25/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0214 - accuracy: 0.9947 - val_loss: 2.1384 - val_accuracy: 0.6942
# Epoch 26/50
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 1.9546 - val_accuracy: 0.6951
# Epoch 27/50
# 137/137 [==============================] - 5s 33ms/step - loss: 0.0386 - accuracy: 0.9874 - val_loss: 1.8441 - val_accuracy: 0.6970
# 43/43 [==============================] - 2s 12ms/step
# Original Normal Sampling Set
#
#              precision    recall  f1-score   support
# neu            0.59607  0.623288  0.609375     438.0
# pos           0.718954  0.697674  0.708155     473.0
# neg           0.747748  0.737778  0.742729     450.0
#
# accuracy      0.686995  0.686995  0.686995  0.686995
# macro avg     0.687591  0.686247  0.686753    1361.0
# weighted avg  0.688928  0.686995  0.687797    1361.0

# %%
# path_1 = os.path.join('Data/final_dataset/', 'COVIDSenti-A_cleanest.csv')
# path_under = '/content/drive/My Drive/final_dataset/resampling/COVIDSenti_cleanest_over.csv'
# df = pd.read_csv(path_under, encoding='utf-8')

# w2v_bilstm(df)


# directory_file_path = '/content/drive/My Drive/final_dataset/'
# file_l = []
# # Loop through the files in the directory to check file names
# for filename in os.listdir(directory_file_path):
#   if filename.endswith('.csv'):
#     file_l.append(filename)  # Check if the file ends with .csv
#     print(filename)

file_l = ['/content/drive/My Drive/final_dataset/COVIDSenti-C_cleanest.csv']

for i in file_l:
  path = i
  print('#'*30, '\n', i,'\n start')
  df = pd.read_csv(path, encoding='utf-8')
  w2v_bilstm(df)
# Out:
# ##############################
#  /content/drive/My Drive/final_dataset/COVIDSenti-C_cleanest.csv
#  start
# vocab size: 3000001
# Epoch 1/50
# 594/594 [==============================] - 28s 37ms/step - loss: 0.6139 - accuracy: 0.7702 - val_loss: 0.5374 - val_accuracy: 0.7915
# Epoch 2/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.4971 - accuracy: 0.8208 - val_loss: 0.4904 - val_accuracy: 0.8151
# Epoch 3/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.4371 - accuracy: 0.8432 - val_loss: 0.4774 - val_accuracy: 0.8238
# Epoch 4/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.3867 - accuracy: 0.8670 - val_loss: 0.4429 - val_accuracy: 0.8347
# Epoch 5/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.3394 - accuracy: 0.8820 - val_loss: 0.4398 - val_accuracy: 0.8404
# Epoch 6/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.2920 - accuracy: 0.8975 - val_loss: 0.4499 - val_accuracy: 0.8438
# Epoch 7/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.2424 - accuracy: 0.9164 - val_loss: 0.4977 - val_accuracy: 0.8471
# Epoch 8/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.1928 - accuracy: 0.9340 - val_loss: 0.5366 - val_accuracy: 0.8406
# Epoch 9/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.1516 - accuracy: 0.9482 - val_loss: 0.5672 - val_accuracy: 0.8408
# Epoch 10/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.1169 - accuracy: 0.9603 - val_loss: 0.6818 - val_accuracy: 0.8395
# Epoch 11/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0904 - accuracy: 0.9690 - val_loss: 0.8057 - val_accuracy: 0.8391
# Epoch 12/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0761 - accuracy: 0.9739 - val_loss: 0.8065 - val_accuracy: 0.8334
# Epoch 13/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0609 - accuracy: 0.9793 - val_loss: 0.9035 - val_accuracy: 0.8400
# Epoch 14/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0511 - accuracy: 0.9829 - val_loss: 0.8761 - val_accuracy: 0.8425
# Epoch 15/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0404 - accuracy: 0.9865 - val_loss: 0.9405 - val_accuracy: 0.8387
# Epoch 16/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.9939 - val_accuracy: 0.8379
# Epoch 17/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0402 - accuracy: 0.9870 - val_loss: 0.9032 - val_accuracy: 0.8410
# Epoch 18/50
# 594/594 [==============================] - 20s 35ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 1.0478 - val_accuracy: 0.8318
# Epoch 19/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0293 - accuracy: 0.9911 - val_loss: 1.0666 - val_accuracy: 0.8423
# Epoch 20/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 1.0414 - val_accuracy: 0.8383
# Epoch 21/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 1.0269 - val_accuracy: 0.8414
# Epoch 22/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 1.1767 - val_accuracy: 0.8444
# Epoch 23/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 1.0410 - val_accuracy: 0.8366
# Epoch 24/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0230 - accuracy: 0.9928 - val_loss: 1.0187 - val_accuracy: 0.8353
# Epoch 25/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 1.1971 - val_accuracy: 0.8423
# Epoch 26/50
# 594/594 [==============================] - 21s 35ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 1.0556 - val_accuracy: 0.8374
# Epoch 27/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0200 - accuracy: 0.9931 - val_loss: 1.1448 - val_accuracy: 0.8368
# Epoch 28/50
# 594/594 [==============================] - 20s 34ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 1.0776 - val_accuracy: 0.8387
# 186/186 [==============================] - 4s 12ms/step
#
#              precision    recall  f1-score   support
# neu           0.879947  0.910304  0.894868    4348.0
# pos           0.641566   0.47651  0.546855     447.0
# neg           0.734417  0.711909  0.722988    1142.0
#
# accuracy      0.839481  0.839481  0.839481  0.839481
# macro avg     0.751977  0.699574   0.72157    5937.0
# weighted avg  0.834006  0.839481  0.835604    5937.0

# %%
directory_file_path = 'Data/final_dataset/'

# Loop through the files in the directory to check file names
for filename in os.listdir(directory_file_path):
    if filename.endswith('.csv'):  # Check if the file ends with .csv
        print(filename)
# Out:
# COVIDSenti-A_cleanest.csv
# COVIDSenti-A_mostfeature.csv
# COVIDSenti-A_origin.csv
# COVIDSenti-B_cleanest.csv
# COVIDSenti-B_mostfeature.csv
# COVIDSenti-B_origin.csv
# COVIDSenti-C_cleanest.csv
# COVIDSenti-C_mostfeature.csv
# COVIDSenti-C_origin.csv
# COVIDSenti_cleanest.csv
# COVIDSenti_mostfeature.csv
# COVIDSenti_origin.csv
